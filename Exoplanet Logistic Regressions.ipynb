# %%
# Dependencies
# %matplotlib inline
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read exoplanet data
df = pd.read_csv("exoplanet_data.csv")
df = df.dropna(axis='columns', how='all')
df = df.dropna()
print(df.describe())
df.head()
# Out:
#        koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# count    6991.000000    6991.000000    6991.000000    6991.000000
# mean        0.157059       0.244743       0.202975       0.125018
# std         0.363882       0.429966       0.402243       0.330763
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#         koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# count  6991.000000     6.991000e+03     6.991000e+03  6991.000000
# mean     56.191248     1.851122e-03    -1.851122e-03   164.488820
# std     117.570962     7.184503e-03     7.184503e-03    67.020475
# min       0.259820     1.100000e-08    -1.568000e-01   120.515914
# 25%       2.620126     5.005000e-06    -2.401000e-04   132.683917
# 50%       8.947426     3.300000e-05    -3.300000e-05   136.739230
# 75%      34.282605     2.401000e-04    -5.005000e-06   169.937005
# max    1071.232624     1.568000e-01    -1.100000e-08  1472.522306
#
#        koi_time0bk_err1  koi_time0bk_err2  ...  koi_steff_err2    koi_slogg  \
# count       6991.000000       6991.000000  ...     6991.000000  6991.000000
# mean           0.009340         -0.009340  ...     -161.206980     4.305049
# std            0.021989          0.021989  ...       71.448481     0.439238
# min            0.000009         -0.569000  ...    -1733.000000     0.047000
# 25%            0.001145         -0.010000  ...     -197.000000     4.209000
# 50%            0.003990         -0.003990  ...     -159.000000     4.436000
# 75%            0.010000         -0.001145  ...     -112.000000     4.543000
# max            0.569000         -0.000009  ...        0.000000     5.364000
#
#        koi_slogg_err1  koi_slogg_err2     koi_srad  koi_srad_err1  \
# count     6991.000000      6991.00000  6991.000000    6991.000000
# mean         0.121091        -0.14048     1.740749       0.352710
# std          0.132048         0.08199     5.903415       0.839017
# min          0.000000        -1.00700     0.109000       0.000000
# 25%          0.044000        -0.19500     0.829000       0.128000
# 50%          0.070000        -0.12700     0.999000       0.248000
# 75%          0.149000        -0.08800     1.357000       0.357000
# max          1.472000         0.00000   180.013000      25.956000
#
#        koi_srad_err2           ra          dec   koi_kepmag
# count    6991.000000  6991.000000  6991.000000  6991.000000
# mean       -0.388568   292.082406    43.812143    14.271508
# std         1.907797     4.762908     3.606167     1.350802
# min      -103.825000   279.856080    36.577381     6.966000
# 25%        -0.252000   288.704730    40.797760    13.455000
# 50%        -0.111000   292.314760    43.679661    14.534000
# 75%        -0.069000   295.888550    46.693659    15.322000
# max         0.000000   301.720760    52.336010    19.065000
#
# [8 rows x 40 columns]
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
print(df.columns)
df_renamed=df.rename(columns={"koi_disposition":"Disposition",
                              "koi_fpflag_nt":"Not Transit Like",
                              "koi_fpflag_ss":"Stellar Eclipse",
                              "koi_fpflag_co":"Centroid Offset",
                              "koi_fpflag_ec":"Ephemeris Match Indicates Contamination",
                              "koi_period":"Orbital Period (Days)",
                              "koi_period_err1":"Orbital Period Positive Error",
                              "koi_period_err2":"Orbital Period Negative Error",
                              "koi_time0bk":"Transit Epoch (BJD - 2,454,833 Days)",
                              "koi_time0bk_err1":"Transit Epoch Positive Error",
                              "koi_time0bk_err2":"Transit Epoch Negative Error",
                              "koi_impact":"Impact",
                              "koi_impact_err1":"Impact Positive Error",
                              "koi_impact_err2":"Impact Negative Error",
                              "koi_duration":"Transit Duration (Hrs)",
                              "koi_duration_err1":"Transit Duration Postive Error",
                              "koi_duration_err2":"Transit Duration Negative Error",
                              "koi_depth":"Transit Depth (Parts/M)",
                              "koi_depth_err1":"Transit Depth Positive Error",
                              "koi_depth_err2":"Transit Depth Negative Error",
                              "koi_prad":"Planetary Radius (Earth Radii)",
                              "koi_prad_err1":"Planetary Radius Positive Error",
                              "koi_prad_err2":"Planetary Radius Negative Error",
                              "koi_teq":"Equilibrium Temperature (K)",
                              "koi_insol":"Insolation Flux (Earth Flux)",
                              "koi_insol_err1":"Insolation Flux Positive Error",
                              "koi_insol_err2":"Insolation Flux Negative Error",
                              "koi_model_snr":"Transit Signal-to-Noise",
                              "koi_tce_plnt_num":"TCE Planet Number",
                              "koi_steff":"Stellar Effective Temperature (K)",
                              "koi_steff_err1":"Stellar Effective Temperature Positive Error",
                              "koi_steff_err2":"Stellar Effective Temperature Negative Error",
                              "koi_slogg":"Stellar Surface Gravity",
                              "koi_slogg_err1":"Stellar Surface Gravity Positive Error",
                              "koi_slogg_err2":"Stellar Surface Gravity Negative Error",
                              "koi_srad":"Stellar Radius (Solar Radii)",
                              "koi_srad_err1":"Stellar Radius Positive Error",
                              "koi_srad_err2":"Stellar Radius Negative Error",
                              "ra":"KIC Right Ascension (Degrees)",
                              "dec":"KIC Declination (Degrees)",
                              "koi_kepmag":"Kepler-band (Magnitude)"
                  })
print(df_renamed.columns)
df_renamed["Confirmed"] = df_renamed["Disposition"].apply(lambda x: 1 if x == "CONFIRMED" else 0)
df_renamed.head()
# Out:
# Index(['koi_disposition', 'koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co',
#        'koi_fpflag_ec', 'koi_period', 'koi_period_err1', 'koi_period_err2',
#        'koi_time0bk', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact',
#        'koi_impact_err1', 'koi_impact_err2', 'koi_duration',
#        'koi_duration_err1', 'koi_duration_err2', 'koi_depth', 'koi_depth_err1',
#        'koi_depth_err2', 'koi_prad', 'koi_prad_err1', 'koi_prad_err2',
#        'koi_teq', 'koi_insol', 'koi_insol_err1', 'koi_insol_err2',
#        'koi_model_snr', 'koi_tce_plnt_num', 'koi_steff', 'koi_steff_err1',
#        'koi_steff_err2', 'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2',
#        'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec',
#        'koi_kepmag'],
#       dtype='object')
# Index(['Disposition', 'Not Transit Like', 'Stellar Eclipse', 'Centroid Offset',
#        'Ephemeris Match Indicates Contamination', 'Orbital Period (Days)',
#        'Orbital Period Positive Error', 'Orbital Period Negative Error',
#        'Transit Epoch (BJD - 2,454,833 Days)', 'Transit Epoch Positive Error',
#        'Transit Epoch Negative Error', 'Impact', 'Impact Positive Error',
#        'Impact Negative Error', 'Transit Duration (Hrs)',
#        'Transit Duration Postive Error', 'Transit Duration Negative Error',
#        'Transit Depth (Parts/M)', 'Transit Depth Positive Error',
#        'Transit Depth Negative Error', 'Planetary Radius (Earth Radii)',
#        'Planetary Radius Positive Error', 'Planetary Radius Negative Error',
#        'Equilibrium Temperature (K)', 'Insolation Flux (Earth Flux)',
#        'Insolation Flux Positive Error', 'Insolation Flux Negative Error',
#        'Transit Signal-to-Noise', 'TCE Planet Number',
#        'Stellar Effective Temperature (K)',
#        'Stellar Effective Temperature Positive Error',
#        'Stellar Effective Temperature Negative Error',
#        'Stellar Surface Gravity', 'Stellar Surface Gravity Positive Error',
#        'Stellar Surface Gravity Negative Error',
#        'Stellar Radius (Solar Radii)', 'Stellar Radius Positive Error',
#        'Stellar Radius Negative Error', 'KIC Right Ascension (Degrees)',
#        'KIC Declination (Degrees)', 'Kepler-band (Magnitude)'],
#       dtype='object')
#       Disposition  Not Transit Like  Stellar Eclipse  Centroid Offset  \
# 0       CONFIRMED                 0                0                0
# 1  FALSE POSITIVE                 0                1                0
# 2  FALSE POSITIVE                 0                1                0
# 3       CONFIRMED                 0                0                0
# 4       CONFIRMED                 0                0                0
#
#    Ephemeris Match Indicates Contamination  Orbital Period (Days)  \
# 0                                        0              54.418383
# 1                                        0              19.899140
# 2                                        0               1.736952
# 3                                        0               2.525592
# 4                                        0               4.134435
#
#    Orbital Period Positive Error  Orbital Period Negative Error  \
# 0                   2.479000e-04                  -2.479000e-04
# 1                   1.490000e-05                  -1.490000e-05
# 2                   2.630000e-07                  -2.630000e-07
# 3                   3.760000e-06                  -3.760000e-06
# 4                   1.050000e-05                  -1.050000e-05
#
#    Transit Epoch (BJD - 2,454,833 Days)  Transit Epoch Positive Error  ...  \
# 0                            162.513840                      0.003520  ...
# 1                            175.850252                      0.000581  ...
# 2                            170.307565                      0.000115  ...
# 3                            171.595550                      0.001130  ...
# 4                            172.979370                      0.001900  ...
#
#    Stellar Surface Gravity  Stellar Surface Gravity Positive Error  \
# 0                    4.467                                   0.064
# 1                    4.544                                   0.044
# 2                    4.564                                   0.053
# 3                    4.438                                   0.070
# 4                    4.486                                   0.054
#
#    Stellar Surface Gravity Negative Error  Stellar Radius (Solar Radii)  \
# 0                                  -0.096                         0.927
# 1                                  -0.176                         0.868
# 2                                  -0.168                         0.791
# 3                                  -0.210                         1.046
# 4                                  -0.229                         0.972
#
#    Stellar Radius Positive Error  Stellar Radius Negative Error  \
# 0                          0.105                         -0.061
# 1                          0.233                         -0.078
# 2                          0.201                         -0.067
# 3                          0.334                         -0.133
# 4                          0.315                         -0.105
#
#    KIC Right Ascension (Degrees)  KIC Declination (Degrees)  \
# 0                      291.93423                  48.141651
# 1                      297.00482                  48.134129
# 2                      285.53461                  48.285210
# 3                      288.75488                  48.226200
# 4                      296.28613                  48.224670
#
#    Kepler-band (Magnitude)  Confirmed
# 0                   15.347          1
# 1                   15.436          0
# 2                   15.597          0
# 3                   15.509          1
# 4                   15.714          1
#
# [5 rows x 42 columns]

# %%
df_all = df_renamed[[
    'Confirmed',
    'Not Transit Like',
    'Stellar Eclipse',
    'Centroid Offset',
    'Ephemeris Match Indicates Contamination',
    'Orbital Period (Days)',
    'Transit Epoch (BJD - 2,454,833 Days)',
    'Impact',
    'Transit Duration (Hrs)',
    'Transit Depth (Parts/M)',
    'Planetary Radius (Earth Radii)',
    'Equilibrium Temperature (K)',
    'Insolation Flux (Earth Flux)',
    'Transit Signal-to-Noise',
    'Stellar Effective Temperature (K)',
    'Stellar Surface Gravity',
    'Stellar Radius (Solar Radii)',
    'KIC Right Ascension (Degrees)',
    'KIC Declination (Degrees)',
    'Kepler-band (Magnitude)'
]]
print(df_all.columns)
df_all.head()
# Out:
# Index(['Confirmed', 'Not Transit Like', 'Stellar Eclipse', 'Centroid Offset',
#        'Ephemeris Match Indicates Contamination', 'Orbital Period (Days)',
#        'Transit Epoch (BJD - 2,454,833 Days)', 'Impact',
#        'Transit Duration (Hrs)', 'Transit Depth (Parts/M)',
#        'Planetary Radius (Earth Radii)', 'Equilibrium Temperature (K)',
#        'Insolation Flux (Earth Flux)', 'Transit Signal-to-Noise',
#        'Stellar Effective Temperature (K)', 'Stellar Surface Gravity',
#        'Stellar Radius (Solar Radii)', 'KIC Right Ascension (Degrees)',
#        'KIC Declination (Degrees)', 'Kepler-band (Magnitude)'],
#       dtype='object')
#    Confirmed  Not Transit Like  Stellar Eclipse  Centroid Offset  \
# 0          1                 0                0                0
# 1          0                 0                1                0
# 2          0                 0                1                0
# 3          1                 0                0                0
# 4          1                 0                0                0
#
#    Ephemeris Match Indicates Contamination  Orbital Period (Days)  \
# 0                                        0              54.418383
# 1                                        0              19.899140
# 2                                        0               1.736952
# 3                                        0               2.525592
# 4                                        0               4.134435
#
#    Transit Epoch (BJD - 2,454,833 Days)  Impact  Transit Duration (Hrs)  \
# 0                            162.513840   0.586                 4.50700
# 1                            175.850252   0.969                 1.78220
# 2                            170.307565   1.276                 2.40641
# 3                            171.595550   0.701                 1.65450
# 4                            172.979370   0.762                 3.14020
#
#    Transit Depth (Parts/M)  Planetary Radius (Earth Radii)  \
# 0                    874.8                            2.83
# 1                  10829.0                           14.60
# 2                   8079.2                           33.46
# 3                    603.3                            2.75
# 4                    686.0                            2.77
#
#    Equilibrium Temperature (K)  Insolation Flux (Earth Flux)  \
# 0                          443                          9.11
# 1                          638                         39.30
# 2                         1395                        891.96
# 3                         1406                        926.16
# 4                         1160                        427.65
#
#    Transit Signal-to-Noise  Stellar Effective Temperature (K)  \
# 0                     25.8                               5455
# 1                     76.3                               5853
# 2                    505.6                               5805
# 3                     40.9                               6031
# 4                     40.2                               6046
#
#    Stellar Surface Gravity  Stellar Radius (Solar Radii)  \
# 0                    4.467                         0.927
# 1                    4.544                         0.868
# 2                    4.564                         0.791
# 3                    4.438                         1.046
# 4                    4.486                         0.972
#
#    KIC Right Ascension (Degrees)  KIC Declination (Degrees)  \
# 0                      291.93423                  48.141651
# 1                      297.00482                  48.134129
# 2                      285.53461                  48.285210
# 3                      288.75488                  48.226200
# 4                      296.28613                  48.224670
#
#    Kepler-band (Magnitude)
# 0                   15.347
# 1                   15.436
# 2                   15.597
# 3                   15.509
# 4                   15.714

# %%
df_boolean = df_all.iloc[:,:5]
df_boolean.groupby(['Confirmed']).mean()
# Out:
#            Not Transit Like  Stellar Eclipse  Centroid Offset  \
# Confirmed
# 0                  0.208245         0.325563         0.272202
# 1                  0.009444         0.011667         0.003333
#
#            Ephemeris Match Indicates Contamination
# Confirmed
# 0                                         0.168176
# 1                                         0.000556

# %%
for column in df_all.columns[5:]:
    if column != "Confirmed":
        print(f"Confirmed by {column}")
        plt.scatter(df_all[column],df_all["Confirmed"])
        plt.show()
# Out:
# Confirmed by Orbital Period (Days)
# Confirmed by Transit Epoch (BJD - 2,454,833 Days)
# Confirmed by Impact
# Confirmed by Transit Duration (Hrs)
# Confirmed by Transit Depth (Parts/M)
# Confirmed by Planetary Radius (Earth Radii)
# Confirmed by Equilibrium Temperature (K)
# Confirmed by Insolation Flux (Earth Flux)
# Confirmed by Transit Signal-to-Noise
# Confirmed by Stellar Effective Temperature (K)
# Confirmed by Stellar Surface Gravity
# Confirmed by Stellar Radius (Solar Radii)
# Confirmed by KIC Right Ascension (Degrees)
# Confirmed by KIC Declination (Degrees)
# Confirmed by Kepler-band (Magnitude)

# %%
y = df_all["Confirmed"]
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       1
#        ..
# 6986    0
# 6987    0
# 6988    0
# 6989    0
# 6990    0
# Name: Confirmed, Length: 6991, dtype: int64

# %%
predictors = [
    "Not Transit Like",
    "Stellar Eclipse",
    "Centroid Offset",
    "Ephemeris Match Indicates Contamination",
    "Impact",
    "Transit Duration (Hrs)",
    "Transit Depth (Parts/M)",
    "Planetary Radius (Earth Radii)",
    "Equilibrium Temperature (K)",
    "Insolation Flux (Earth Flux)",
    "Transit Signal-to-Noise",
    "Stellar Effective Temperature (K)",
    "Stellar Surface Gravity",
    "Stellar Radius (Solar Radii)"
]
predictors_series = df_all[[
    "Not Transit Like",
    "Stellar Eclipse",
    "Centroid Offset",
    "Ephemeris Match Indicates Contamination",
    "Impact",
    "Transit Duration (Hrs)",
    "Transit Depth (Parts/M)",
    "Planetary Radius (Earth Radii)",
    "Equilibrium Temperature (K)",
    "Insolation Flux (Earth Flux)",
    "Transit Signal-to-Noise",
    "Stellar Effective Temperature (K)",
    "Stellar Surface Gravity",
    "Stellar Radius (Solar Radii)"
]]
predictors_series.head()
# Out:
#    Not Transit Like  Stellar Eclipse  Centroid Offset  \
# 0                 0                0                0
# 1                 0                1                0
# 2                 0                1                0
# 3                 0                0                0
# 4                 0                0                0
#
#    Ephemeris Match Indicates Contamination  Impact  Transit Duration (Hrs)  \
# 0                                        0   0.586                 4.50700
# 1                                        0   0.969                 1.78220
# 2                                        0   1.276                 2.40641
# 3                                        0   0.701                 1.65450
# 4                                        0   0.762                 3.14020
#
#    Transit Depth (Parts/M)  Planetary Radius (Earth Radii)  \
# 0                    874.8                            2.83
# 1                  10829.0                           14.60
# 2                   8079.2                           33.46
# 3                    603.3                            2.75
# 4                    686.0                            2.77
#
#    Equilibrium Temperature (K)  Insolation Flux (Earth Flux)  \
# 0                          443                          9.11
# 1                          638                         39.30
# 2                         1395                        891.96
# 3                         1406                        926.16
# 4                         1160                        427.65
#
#    Transit Signal-to-Noise  Stellar Effective Temperature (K)  \
# 0                     25.8                               5455
# 1                     76.3                               5853
# 2                    505.6                               5805
# 3                     40.9                               6031
# 4                     40.2                               6046
#
#    Stellar Surface Gravity  Stellar Radius (Solar Radii)
# 0                    4.467                         0.927
# 1                    4.544                         0.868
# 2                    4.564                         0.791
# 3                    4.438                         1.046
# 4                    4.486                         0.972

# %%
# Logistic Regression
output = pd.DataFrame(columns = ["Variable","Intercept","Coefficient","Training Score","Testing Score"])
index = 0
for predictor in predictors:
    y = df_all["Confirmed"]
    X = df_all[[predictor]]
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)
    classifier = LogisticRegression()
    classifier.fit(X_train, y_train)
    train_score = classifier.score(X_train, y_train)
    test_score = classifier.score(X_test, y_test)
    trained_regressor = LogisticRegression().fit(X_test, y_test)
    output = output.append({
        "Variable": predictor,
        "Intercept": trained_regressor.intercept_[0],
        "Coefficient": trained_regressor.coef_[0][0],
        "Training Score": train_score,
        "Testing Score": test_score},
        ignore_index=True)
    index = index + 1
output = output.sort_values(by=["Coefficient"])
plt.barh(output["Variable"],output["Coefficient"])
plt.show()
output
# Out:
#                                    Variable     Intercept  Coefficient  \
# 1                           Stellar Eclipse -6.647774e-01    -3.413226
# 2                           Centroid Offset -7.690481e-01    -3.374228
# 3   Ephemeris Match Indicates Contamination -8.901399e-01    -3.063982
# 0                          Not Transit Like -8.527175e-01    -2.786178
# 4                                    Impact -5.107019e-01    -1.063886
# 13             Stellar Radius (Solar Radii) -2.484398e-01    -0.698546
# 7            Planetary Radius (Earth Radii) -4.618683e-01    -0.088591
# 5                    Transit Duration (Hrs) -7.046268e-01    -0.071421
# 10                  Transit Signal-to-Noise -8.801868e-01    -0.001111
# 8               Equilibrium Temperature (K) -3.233679e-01    -0.000768
# 9              Insolation Flux (Earth Flux) -8.056331e-01    -0.000328
# 11        Stellar Effective Temperature (K) -2.908864e-08    -0.000192
# 6                   Transit Depth (Parts/M) -8.080050e-01    -0.000050
# 12                  Stellar Surface Gravity -6.482665e+00     1.241993
#
#     Training Score  Testing Score
# 1         0.742514       0.742563
# 2         0.742514       0.742563
# 3         0.742514       0.742563
# 0         0.742514       0.742563
# 4         0.742514       0.742563
# 13        0.742514       0.742563
# 7         0.742514       0.742563
# 5         0.742514       0.742563
# 10        0.742514       0.742563
# 8         0.742514       0.742563
# 9         0.742514       0.742563
# 11        0.742514       0.742563
# 6         0.742514       0.742563
# 12        0.742323       0.742563
